# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pylab as plt

# %%
y_1 = pd.read_csv("SuperStoreOrders.csv")
df = y_1.head(20000)

# %%
y_1
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
y_1.shape
# Out:
# (51290, 21)

# %%
y_1.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
y_1['sales'].unique()
# Out:
# array(['408', '120', '66', ..., '1,763', '1,821', '1,831'], dtype=object)

# %% [markdown]
# ## LinePlot

# %%
sns.lineplot(x="quantity",y="discount",data=df,hue='segment',style='ship_mode',palette='brg', size='category',markers=True)
plt.grid()
plt.show()

# %% [markdown]
# ## BarPlot

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd

# %%
new = sns.load_dataset("penguins")
new
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# ## What are the black lines on the bar ?
#
# the black lines on the top middle of the bars typically represent error bars. Error bars provide a visual representation of the variability or uncertainty in the data being represented by each bar.
#
# Error bars are commonly used to show the range of uncertainty around the mean or average value of each bar. They can convey information about the variability of the data points or the level of confidence in the measurement.
#
# The length of the error bars can vary based on the type of error represented. Commonly used error bars include:
#
# Standard Error (SE): The error bars represent the standard error of the mean, which provides a measure of how much the sample means are expected to vary from the true population mean.
#
# Confidence Intervals (CI): The error bars represent the confidence intervals, typically at 95% confidence level, which indicates the range within which the true population mean is likely to lie.
#
# Standard Deviation (SD): The error bars represent the standard deviation, which measures the spread of the data points around the mean.
#
# Custom Error Values: You can also calculate and plot custom error values based on your specific analysis or experiment.
#
# Error bars are useful for comparing different bar heights and understanding the uncertainty associated with each bar's value. They provide a more complete picture of the data distribution and can help in drawing meaningful conclusions from the graph.
#
# Keep in mind that error bars are not always present in bar graphs. Whether to include error bars depends on the specific context of the data and the purpose of the visualization. In many cases, you can control the display of error bars using plotting functions in libraries like Matplotlib or Seaborn by specifying the appropriate parameters.

# %%
sns.set(style = "darkgrid")
sns.barplot(x='island',y='bill_length_mm',hue='sex',data=new,hue_order=["Female","Male"],ci=100,n_boot=5,saturation=150,errcolor="r",capsize=0.37)
plt.show()
# Out:
# C:\Users\SHUBHI\AppData\Local\Temp\ipykernel_29908\228653829.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x='island',y='bill_length_mm',hue='sex',data=new,hue_order=["Female","Male"],ci=100,n_boot=5,saturation=150,errcolor="r",capsize=0.37)

# %% [markdown]
# ## For my further understanding !
#
# **Syntax:-**
#
# seaborn.barplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, estimator='mean', errorbar=('ci', 95), n_boot=1000, units=None, seed=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, errcolor='.26', errwidth=None, capsize=None, dodge=True, ci='deprecated', ax=None, **kwargs)

# %%
sns.barplot(x='bill_depth_mm',y='bill_length_mm',hue='sex',data=new,hue_order=["Female","Male"],ci=100,n_boot=5,orient="h")
plt.show()
# Out:
# C:\Users\SHUBHI\AppData\Local\Temp\ipykernel_29908\3374560484.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x='bill_depth_mm',y='bill_length_mm',hue='sex',data=new,hue_order=["Female","Male"],ci=100,n_boot=5,orient="h")

# %% [markdown]
# ## HistogramPlot

# %% [markdown]
# **SYNTAX :-**
#
# seaborn.distplot(a=None, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None, x=None)

# %%
data = sns.load_dataset("penguins")
data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.distplot(data["flipper_length_mm"],bins=10,color="g",rug=True)
plt.show()
# Out:
# C:\Users\SHUBHI\AppData\Local\Temp\ipykernel_29908\2209955569.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["flipper_length_mm"],bins=10,color="g",rug=True)

# %% [markdown]
# ## ScatterPlot
#
# **SYNTAX :-**
#
# seaborn.scatterplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, legend='auto', ax=None, **kwargs)
# Draw a scatter plot with possibility of several semantic groupings.

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=data,hue='sex',size="island",style="species",palette='gist_ncar')
plt.show()

# %% [markdown]
# ## HeatMap

# %% [markdown]
# **SYNTAX :-**
#
# seaborn.heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)

# %%
var = np.linspace(1,10,20).reshape(4,5)
var
# Out:
# array([[ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684],
#        [ 3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789],
#        [ 5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895],
#        [ 8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]])

# %%
sns.heatmap(var,vmin=0,vmax=20,cmap='gist_heat',annot=True)
# Out:
# <Axes: >

# %%
Data = sns.load_dataset("anagrams")
Data
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
d = Data.drop(columns=["attnr"],axis=1).head(10)

# %%
sns.heatmap(d,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # CountPlot
#
# **Syntax :-**
#
# seaborn.countplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, ax=None, **kwargs)
# Show the counts of observations in each categorical bin using bars.
#
# Here the major difference between count plot and bar plot is that it gives the actual count where as barplot gives the mean/median of the data

# %%
tip = pd.read_csv("tips.csv")
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(data=tip,x="sex",hue="smoker",palette='bwr')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## ViolinPlot
#
# A violin plot plays a similar role as box and whiskers ploy . It shows the distribution of a quantitative data across several levels of one (or more) categorical variables such that those distribution can be conpared
#
# Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.
#
# This can be an effective and attractive way to show multiple distributions of data at once, but keep in mind that the estimation procedure is influenced by the sample size, and violins for relatively small samples might look misleadingly smooth.
#
# **SYNTAX :-**
#
# seaborn.violinplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, bw='scott', cut=2, scale='area', scale_hue=True, gridsize=100, width=0.8, inner='box', split=False, dodge=True, orient=None, linewidth=None, color=None, palette=None, saturation=0.75, ax=None, **kwargs)
#
# Draw a combination of boxplot and kernel density estimate.

# %%
tip.shape
# Out:
# (244, 7)

# %%
sns.violinplot(x="day",y="total_bill",data=tip,hue="time",linewidth=2,palette='spring')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="time",y="total_bill",data=tip,linewidth=2,palette='spring',order=['Dinner','Lunch'],saturation=1)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tip,linewidth=2,palette='spring',hue="sex",split=True,saturation=1,scale="count")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tip,linewidth=2,palette='spring',hue="sex",split=True,saturation=1,inner="quart") #{"box","quatile","point","stick"} within inner parameter
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="total_bill",data=tip)
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# ## PairPlot
#
# Plot pairwise relationships in a dataset.
#
# By default, this function will create a grid of Axes such that each numeric variable in data will by shared across the y-axes across a single row and the x-axes across a single column. The diagonal plots are treated differently: a univariate distribution plot is drawn to show the marginal distribution of the data in each column.
#
# It is also possible to show a subset of variables or plot different variables on the rows and columns.
#
# This is a high-level interface for PairGrid that is intended to make it easy to draw a few common styles. You should use PairGrid directly if you need more flexibility.
#
# **SYNTAX :-**
#
# seaborn.pairplot(data, *, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, corner=False, dropna=False, plot_kws=None, diag_kws=None, grid_kws=None, size=None)

# %%
sns.pairplot(tip,vars=['total_bill','tip'],hue="sex",palette='hsv')
plt.show()

# %%
sns.pairplot(tip,hue="sex",palette='hsv',y_vars=["total_bill","tip"])

# %%
sns.pairplot(tip,hue="sex",palette='hsv',kind="kde") #scatter,kde,hist,reg within kind

# %%
sns.pairplot(tip,hue="sex",palette='hsv',kind="kde",diag_kind="hist") #scatter,kde,hist,reg within kind

# %%
sns.pairplot(tip,hue="sex",palette='hsv',markers=["*","^"])

# %% [markdown]
# ## Stripplot
#
# A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
# **SYNTAX :-**
#
# seaborn.stripplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, jitter=True, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, hue_norm=None, native_scale=False, formatter=None, legend='auto', ax=None, **kwargs)

# %%
# import matplotlib.markers as mmarkers
m = {"Male":"<","Female":">"}
# marker = mmarkers.MarkerStyle(marker=['D','s'], fillstyle='none')
sns.stripplot(data=tip,x="day",y="total_bill",palette='husl',hue = "sex", size=10, edgecolor='gray',linewidth=1,dodge=0.5,marker = ">")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Boxplot
#
# **SYNTAX :-**
#
# seaborn.boxplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)

# %%
sns.set(style="whitegrid")

# %%
sns.boxplot(data=tip,x="day",y="total_bill",hue="sex",showmeans=True, saturation=0.75, width=0.8, dodge=True, fliersize=5,palette="cubehelix")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## CatPlot
#
# This function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations. The kind parameter selects the underlying axes-level function to use:
#
# **Categorical scatterplots:**
#
# stripplot() (with kind="strip"; the default)
#
# swarmplot() (with kind="swarm")
#
# **Categorical distribution plots:**
#
# boxplot() (with kind="box")
#
# violinplot() (with kind="violin")
#
# boxenplot() (with kind="boxen")
#
# **Categorical estimate plots:**
#
# pointplot() (with kind="point")
#
# barplot() (with kind="bar")
#
# countplot() (with kind="count")
#
# **SYNTAX :-**
#
# seaborn.catplot(data=None, *, x=None, y=None, hue=None, row=None, col=None, col_wrap=None, estimator='mean', errorbar=('ci', 95), n_boot=1000, units=None, seed=None, order=None, hue_order=None, row_order=None, col_order=None, height=5, aspect=1, kind='strip', native_scale=False, formatter=None, orient=None, color=None, palette=None, hue_norm=None, legend='auto', legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, ci='deprecated', **kwargs)

# %%
t = tip.head(25)

# %%
sns.catplot(x="tip",y="size",data=tip,palette='OrRd',hue="sex",height=10,kind="point")

# %% [markdown]
# ## Facet-Grid Plot
#
# This class maps a dataset onto multiple axes arrayed in a grid of rows and columns that correspond to levels of variables in the dataset. The plots it produces are often called “lattice”, “trellis”, or “small-multiple” graphics.
#
# It can also represent levels of a third variable with the hue parameter, which plots different subsets of data in different colors. This uses color to resolve elements on a third dimension, but only draws subsets on top of each other and will not tailor the hue parameter for the specific visualization the way that axes-level functions that accept hue will.
#
# **SYNTAX :-**
#
# seaborn.FacetGrid(data, *, row=None, col=None, hue=None, col_wrap=None, sharex=True, sharey=True, height=3, aspect=1, palette=None, row_order=None, col_order=None, hue_order=None, hue_kws=None, dropna=False, legend_out=True, despine=True, margin_titles=False, xlim=None, ylim=None, subplot_kws=None, gridspec_kws=None)

# %%
fg = sns.FacetGrid(tip,col="day",hue="sex",height=5)
fg.map(plt.scatter,"total_bill","tip").add_legend()

# %%
fg = sns.FacetGrid(tip,col="day",hue="sex",height=5)
fg.map(plt.bar,"total_bill","tip").add_legend()
